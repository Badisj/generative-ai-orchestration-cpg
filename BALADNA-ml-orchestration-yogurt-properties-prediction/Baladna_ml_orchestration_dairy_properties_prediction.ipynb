# %%
import os

# %%
os.chdir(r"C:\Users\mji11\Desktop\Machine Learning Orchestration\ai-ml-orchestration-cpg\BALADNA-ml-orchestration-yogurt-properties-prediction")

# %% [markdown]
# ### 1. Feature engineering and target estimation

# %%
# Run script to generate all features
# !python "src\yogurt_feature_engineering_all_features.py" --input_excel "./data/generated/Recipe_yogurt_generated.xlsx"  --output_csv "./data/processed/Recipe_yogurt_data_generated_with_all_features.csv"

# %%
# Run to estimate targets based on core features
# !python "src\yogurt_target_estimation.py" --input_csv "./data/processed/Recipe_yogurt_data_generated_with_all_features.csv"  --output_csv "./data/processed/Recipe_yogurt_data_generated_with_all_features_and_targets.csv"
# Out:
# Yogurt Realistic Target Estimator
# ...
# Estimating yogurt quality targets using industry-realistic correlations...
# Computing Tier 1 targets...
# Computing Tier 2 targets...
# Computing additional targets...
# Successfully estimated 13 target variables
# YOGURT TARGET ESTIMATION SUMMARY REPORT
# ...
#
# Dataset size: 300 samples
# Total features: 100
# Estimated targets: 20
#
# TARGET STATISTICS:
# ------------------------------
# base_color_L             : mean=180.942, std=39.874, range=[87.100, 288.092]
# base_color_a             : mean=25.544, std=7.853, range=[16.375, 52.000]
# base_color_b             : mean=12.416, std=3.888, range=[8.054, 20.456]
# color_L_predicted        : mean=161.997, std=63.944, range=[-136.000, 286.492]
# color_L_star             : mean=91.589, std=11.611, range=[50.000, 95.000]
# color_a_predicted        : mean=29.000, std=10.776, range=[16.375, 71.125]
# color_a_star             : mean=15.899, std=5.618, range=[6.735, 25.000]
# ...

# %%
# Run to generate the core features only
# !python "src\yogurt_feature_engineering_core_features.py" --input_excel "./data/generated/Recipe_yogurt_generated.xlsx"  --output_csv "./data/processed/Recipe_yogurt_data_generated_with_core_features.csv"
# Out:
# CORE FEATURES BY TARGET (Optimized for R² > 0.85)
# ...
#
# Viscosity:
#   Features (6): ['texture_synergy_score', 'fat_globule_size_predicted', 'protein_network_strength']...
#
# Firmness:
#   Features (6): ['casein_whey_ratio', 'protein_network_strength', 'texture_synergy_score']...
#
# Syneresis:
#   Features (6): ['stabilizer_efficiency', 'protein_network_strength', 'casein_whey_ratio']...
#
# pH_Evolution:
#   Features (5): ['acidification_adjusted', 'substrate_quality', 'pH_buffering_capacity']...
#
# Fermentation_Endpoint:
#   Features (5): ['acidification_adjusted', 'substrate_quality', 'pH_buffering_capacity']...
#
# Graininess_Perception:
#   Features (5): ['consumer_graininess_perception', 'fat_globule_size_predicted', 'particle_uniformity']...
#
# Visual_Smoothness:
#   Features (5): ['fat_globule_size_predicted', 'particle_uniformity', 'homog_energy_density']...
#
# Consumer_Acceptance:
# ...

# %%
# Run to estimate targets based on core features
# !python "src\yogurt_target_estimation.py" --input_csv "./data/processed/Recipe_yogurt_data_generated_with_core_features.csv"  --output_csv "./data/processed/Recipe_yogurt_data_generated_with_core_features_and_targets.csv"
# Out:
# Yogurt Realistic Target Estimator
# ...
# Estimating yogurt quality targets using industry-realistic correlations...
# Computing Tier 1 targets...
# Computing Tier 2 targets...
# Computing additional targets...
# Successfully estimated 13 target variables
# YOGURT TARGET ESTIMATION SUMMARY REPORT
# ...
#
# Dataset size: 300 samples
# Total features: 100
# Estimated targets: 20
#
# TARGET STATISTICS:
# ------------------------------
# base_color_L             : mean=180.942, std=39.874, range=[87.100, 288.092]
# base_color_a             : mean=25.544, std=7.853, range=[16.375, 52.000]
# base_color_b             : mean=12.416, std=3.888, range=[8.054, 20.456]
# color_L_predicted        : mean=161.997, std=63.944, range=[-136.000, 286.492]
# color_L_star             : mean=91.589, std=11.611, range=[50.000, 95.000]
# color_a_predicted        : mean=29.000, std=10.776, range=[16.375, 71.125]
# color_a_star             : mean=15.899, std=5.618, range=[6.735, 25.000]
# ...
